# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('pokedex_(Update_05.20).csv')
df.head()
# Out:
#    Unnamed: 0  pokedex_number           name german_name        japanese_name  \
# 0           0               1      Bulbasaur     Bisasam  フシギダネ (Fushigidane)
# 1           1               2        Ivysaur   Bisaknosp   フシギソウ (Fushigisou)
# 2           2               3       Venusaur    Bisaflor  フシギバナ (Fushigibana)
# 3           3               3  Mega Venusaur    Bisaflor  フシギバナ (Fushigibana)
# 4           4               4     Charmander    Glumanda      ヒトカゲ (Hitokage)
#
#    generation  status         species  type_number type_1  ... against_ground  \
# 0           1  Normal    Seed Pokémon            2  Grass  ...            1.0
# 1           1  Normal    Seed Pokémon            2  Grass  ...            1.0
# 2           1  Normal    Seed Pokémon            2  Grass  ...            1.0
# 3           1  Normal    Seed Pokémon            2  Grass  ...            1.0
# 4           1  Normal  Lizard Pokémon            1   Fire  ...            2.0
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'pokedex_number', 'name', 'german_name', 'japanese_name',
#        'generation', 'status', 'species', 'type_number', 'type_1', 'type_2',
#        'height_m', 'weight_kg', 'abilities_number', 'ability_1', 'ability_2',
#        'ability_hidden', 'total_points', 'hp', 'attack', 'defense',
#        'sp_attack', 'sp_defense', 'speed', 'catch_rate', 'base_friendship',
#        'base_experience', 'growth_rate', 'egg_type_number', 'egg_type_1',
#        'egg_type_2', 'percentage_male', 'egg_cycles', 'against_normal',
#        'against_fire', 'against_water', 'against_electric', 'against_grass',
#        'against_ice', 'against_fight', 'against_poison', 'against_ground',
#        'against_flying', 'against_psychic', 'against_bug', 'against_rock',
#        'against_ghost', 'against_dragon', 'against_dark', 'against_steel',
#        'against_fairy'],
#       dtype='object')

# %%
df.shape
# Out:
# (1028, 51)

# %%
df.describe()
# Out:
#         Unnamed: 0  pokedex_number   generation  type_number     height_m  \
# count  1028.000000     1028.000000  1028.000000  1028.000000  1028.000000
# mean    513.500000      437.711089     4.034047     1.527237     1.368093
# std     296.902341      259.366480     2.234937     0.499501     3.380126
# min       0.000000        1.000000     1.000000     1.000000     0.100000
# 25%     256.750000      213.750000     2.000000     1.000000     0.600000
# 50%     513.500000      433.500000     4.000000     2.000000     1.000000
# 75%     770.250000      663.250000     6.000000     2.000000     1.500000
# max    1027.000000      890.000000     8.000000     2.000000   100.000000
#
#          weight_kg  abilities_number  total_points           hp       attack  \
# count  1027.000000       1028.000000   1028.000000  1028.000000  1028.000000
# mean     69.753749          2.284047    437.571984    69.577821    80.119650
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 51 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1028 non-null   int64
#  1   pokedex_number    1028 non-null   int64
#  2   name              1028 non-null   object
#  3   german_name       938 non-null    object
#  4   japanese_name     938 non-null    object
#  5   generation        1028 non-null   int64
#  6   status            1028 non-null   object
#  7   species           1028 non-null   object
#  8   type_number       1028 non-null   int64
#  9   type_1            1028 non-null   object
#  10  type_2            542 non-null    object
#  11  height_m          1028 non-null   float64
#  12  weight_kg         1027 non-null   float64
#  13  abilities_number  1028 non-null   int64
#  14  ability_1         1025 non-null   object
#  15  ability_2         513 non-null    object
# ...

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# egg_type_2          746
# ability_2           515
# type_2              486
# percentage_male     236
# ability_hidden      218
# base_experience     104
# base_friendship     104
# catch_rate          104
# japanese_name        90
# german_name          90
# ability_1             3
# egg_type_1            3
# growth_rate           1
# egg_cycles            1
# weight_kg             1
# name                  0
# pokedex_number        0
# Unnamed: 0            0
# generation            0
# hp                    0
# total_points          0
# height_m              0
# abilities_number      0
# status                0
# species               0
# type_number           0
# type_1                0
# speed                 0
# defense               0
# sp_attack             0
# sp_defense            0
# attack                0
# egg_type_number       0
# against_normal        0
# against_fire          0
# against_water         0
# against_electric      0
# against_grass         0
# ...

# %%
ax = df["type_1"].value_counts().plot(kind = 'bar', title = 'Count of pokemon types', colormap = 'Oranges')
ax.set_xlabel('Types')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.groupby(by=["type_1", "type_2"]).size()
# Out:
# type_1  type_2
# Bug     Electric     4
#         Fairy        2
#         Fighting     4
#         Fire         2
#         Flying      14
#                     ..
# Water   Ice          4
#         Poison       3
#         Psychic      6
#         Rock         5
#         Steel        1
# Length: 171, dtype: int64

# %%
ax = df["hp"].plot(kind = 'hist', colormap = 'viridis', title = 'HP values of Pokemon')
ax.set_xlabel("HP values")
# Out:
# Text(0.5, 0, 'HP values')

# %%
ax = df["attack"].plot(kind = 'hist', colormap = 'viridis', title = 'Attack values of Pokemon')
ax.set_xlabel("Attack Values")
# Out:
# Text(0.5, 0, 'Attack Values')

# %%
ax = df["defense"].plot(kind = 'hist', colormap = 'viridis', title = 'Defense values of Pokemon')
ax.set_xlabel("Defense values")
# Out:
# Text(0.5, 0, 'Defense values')

# %%
ax = df["sp_attack"].plot(kind = 'hist', colormap = 'viridis', title = 'Special attack values of Pokemon')
ax.set_xlabel("Special Attack values")
# Out:
# Text(0.5, 0, 'Special Attack values')

# %%
ax = df["sp_defense"].plot(kind = 'hist', colormap = 'viridis', title = 'Special defense values of Pokemon')
ax.set_xlabel("Special Defense values")
# Out:
# Text(0.5, 0, 'Special Defense values')

# %%
ax = df["speed"].plot(kind = 'hist', colormap = 'viridis', title = 'Speed values of Pokemon')
ax.set_xlabel("Speed values")
# Out:
# Text(0.5, 0, 'Speed values')
